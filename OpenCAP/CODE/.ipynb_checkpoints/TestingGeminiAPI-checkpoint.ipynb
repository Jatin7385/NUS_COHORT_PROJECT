# %% [markdown]
# #### Declaring the API Key

# %%
API_KEY = "AIzaSyBejBS4KXsfmxP4IAXCfilUCcsecHC1MTA"

# %% [markdown]
# #### Importing the necessary packages

# %%
import pathlib
import textwrap

import google.generativeai as genai
from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %% [markdown]
# #### Configure the model with the API Key

# %%
genai.configure(api_key=API_KEY)

# %% [markdown]
# #### List the models available

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-pro
# models/gemini-pro-vision

# %% [markdown]
# #### Load the Image

# %%
import PIL.Image

img = PIL.Image.open('../GraphTest.png')
img
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\PIL\JpegImagePlugin.py:639, in _save(im, fp, filename)
#     638 try:
# --> 639     rawmode = RAWMODE[im.mode]
#     640 except KeyError as e:
#
# KeyError: 'RGBA'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\PIL\Image.py:643, in Image._repr_image(self, image_format, **kwargs)
#     642 try:
# --> 643     self.save(b, image_format, **kwargs)
#     644 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\PIL\Image.py:2413, in Image.save(self, fp, format, **params)
#    2412 try:
# -> 2413     save_handler(self, fp, filename)
#    2414 except Exception:
#
# ...

# %% [markdown]
# #### Using the Gemini-pro-vision model

# %%
model = genai.GenerativeModel('gemini-pro-vision')

# %%
response = model.generate_content(img)

to_markdown(response.text)
# Out:
# >  1966: Conservative - 364, Labour - 317, Liberal - 12, Others - 23
# > 1970: Conservative - 330, Labour - 287, Liberal - 6, Others - 33
# > 1974 Feb: Conservative - 297, Labour - 301, Liberal - 14, Others - 23
# > 1974 Oct: Conservative - 277, Labour - 319, Liberal - 13, Others - 22
# > 1979: Conservative - 339, Labour - 269, Liberal - 11, Others - 11
# > 1983: Conservative - 397, Labour - 209, Liberal - 17, Others - 23
# > 1987: Conservative - 376, Labour - 229, Liberal - 22, Others - 23
# > 1992: Conservative - 336, Labour - 271, Liberal - 20, Others - 22
# > 1997: Conservative - 165, Labour - 418, Liberal - 46, Others - 24
# > 2001: Conservative - 166, Labour - 413, Liberal - 52, Others - 32
# > 2005: Conservative - 198, Labour - 356, Liberal - 62, Others - 46
# > 2010: Conservative - 306, Labour - 258, Liberal - 57, Others - 29
# > 2015: Conservative - 330, Labour - 232, Liberal - 8, Others - 59
# > 2017: Conservative - 317, Labour - 262, Liberal - 12, Others - 53
# ...

# %% [markdown]
# #### Getting a bit more specific

# %%
response = model.generate_content(["Write a short, engaging blog post based on this picture.", img], stream=True)
response.resolve()

# %%
to_markdown(response.text)
# Out:
# >  **British elections: A brief history**
# >
# > The United Kingdom has a long and storied history of democracy, with elections being held for centuries. The first recorded election in the UK was held in 1265, when Simon de Montfort was elected as the first Earl of Leicester.
# >
# > Elections in the UK are held on a first-past-the-post system, meaning that the candidate who receives the most votes in a constituency is elected as the representative for that constituency. This system has been in place since the 18th century, and has been used in every general election since then.
# >
# > The UK has a two-party system, with the Conservative Party and the Labour Party being the two main parties. Other parties, such as the Liberal Democrats, the Scottish National Party, and the Plaid Cymru, also have representation in Parliament.
# >
# ...
